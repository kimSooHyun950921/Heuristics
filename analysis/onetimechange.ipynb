# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/dnlab/DataHDD/otc_cluster.csv')

# %%
midf = pd.read_csv('/home/dnlab/DataHDD/tag_v2.csv')

# %%
zerodf = len(df[df['len']== 1])
onedf = len(df[df['len'] < 10])
twodf = len(df[(df['len'] >= 10) & (df['len']<100)])
threedf = len( df[(df['len'] >= 100) & (df['len']<1000)])
#fourdf = len(df[(df['len'] >= 500) & (df['len']<1000)])
fivedf = len(df[(df['len'] >= 1000) & (df['len']<10000)])
sixdf = len(df[(df['len'] >= 10000) & (df['len']<100000)])
sevendf = len(df[(df['len'] >= 100000) & (df['len']<1000000)])
eightdf = len(df[(df['len'] >= 1000000)  & (df['len']<10000000)])
ninedf = len(df[(df['len'] >= 10000000)  & (df['len']<100000000)])
tendf = df[df['len'] > 100000000]

new_df = df[df['len'] >= 100]

# %%
tendf
# Out:
#        group  smallest_addr        len
# 1254  139414          65394  177430709

# %%
midf = pd.read_csv('/home/dnlab/DataHDD/tag_v2.csv')
mizerodf = len(midf[midf['len']== 1])
mionedf = len(midf[midf['len'] < 10])
mitwodf = len(midf[(midf['len'] >= 10) & (midf['len']<100)])
mithreedf = len( midf[(midf['len'] >= 100) & (midf['len']<1000)])
#fourdf = len(midf[(midf['len'] >= 500) & (midf['len']<1000)])
mifivedf = len(midf[(midf['len'] >= 1000) & (midf['len']<10000)])
misixdf = len(midf[(midf['len'] >= 10000) & (midf['len']<100000)])
misevendf = len(midf[(midf['len'] >= 100000) & (midf['len']<1000000)])
mieightdf = len(midf[(midf['len'] >= 1000000)  & (midf['len']<10000000)])
mininedf = len(midf[(midf['len'] >= 10000000)  & (midf['len']<100000000)])
mitendf = len(midf[midf['len'] > 100000000])

new_df = midf[midf['len'] >= 100]

# %%
otcy = [onedf ,twodf, threedf, fivedf,sixdf, sevendf, eightdf, ninedf, tendf]
x = np.arange(len(y))#[1,2,3,4,5,6,7,8]
y_label = ['$[10^0, 10^1)$', '$[10^1, 10^2)$', '$[10^2, 10^3)$', '$[10^3, 10^4)$', '$[10^4, 10^5)$', \
           '$[10^5, 10^6)$', '$[10^6, 10^7)$', '$[10^7, 10^8)$','$[10^8, 10^9)$']
y_text = [59257451, 2502810, 149945, 6999, 970, 215, 15, 2]
y_text = ['$0.0x10^0$', '$2.2x10^6$', '$1.3x10^5$', '$3.4x10^3$', '$1.3x10^2$', '$2.2x10^2$', '$1.5x10^1$', '$0.0x10^0$','$0.0x10^0$','$1.0x10^0$']

Z = df['len'].to_list()
Z.sort()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)

#[59257451, 2502810, 149945, 6999, 970, 215, 15, 2]

#ax.grid(True)
#ax.legend(loc='right')
#ax.set_xscale('log')

fig = plt.figure(figsize=(12,6))
grid = plt.GridSpec(1, 16, hspace=0.2, wspace=0.2)
ax1 = fig.add_subplot(grid[5:])
ax2 = fig.add_subplot(grid[:4])

bars = ax1.bar(y_label,y, 0.9)

for index, rect in enumerate(bars):
    height = rect.get_height()
    ax1.annotate('{}'.format(y_text[index]),
                xy=(rect.get_x(), height),va='bottom')
    
ax1.set_yscale('log')
ax1.set_xticklabels(y_label, rotation=15)
ax1.set_ylabel('Number of cluster', fontsize=14)

ax2.plot(X2, F2,label='Cluster Size')
ax2.axhline(y=0.95, color='red', linestyle='dotted')
ax2.axvline(x=Z[int(len(Z)*0.95)],color='red', linestyle='dotted')
ax2.text(Z[int(len(Z)*0.95)]+10, 0.9, f'({Z[int(len(Z)*0.95)]},0.95)', fontsize=10)
#ax2.set_xlabel('Number of address in cluster', fontsize=15)
ax2.set_ylabel('Total cluster percentage', fontsize=14)
ax2.set_xscale('log')


#ax.axis([1, 1000, 1, 100000000])
plt.xlabel('Number of address in cluster', fontsize= 14, horizontalalignment='center', position=(1.5,25), labelpad=20)

plt.show()

# %%
miy = [mionedf ,mitwodf, mithreedf, mifivedf, misixdf, misevendf, mieightdf, mininedf, mitendf]
otcy = [onedf ,twodf, threedf, fivedf,sixdf, sevendf, eightdf, ninedf, tendf]
x = np.arange(len(miy))
y_range = [1,2,3,4,5,6,7,8,9]

y_label = ['$[10^0, 10^1)$', '$[10^1, 10^2)$', '$[10^2, 10^3)$', '$[10^3, 10^4)$', '$[10^4, 10^5)$', \
           '$[10^5, 10^6)$', '$[10^6, 10^7)$', '$[10^7, 10^8)$','$[10^8, 10^9)$']
mi_label = [' ', ' ', ' ', ' ', ' ', ' ', ' ',' ',' ']

mi_text = ['$5.9x10^7$', '$2.5x10^6$', '$1.5x10^5$', '$6.9x10^3$', '$9.7x10^2$', '$2.2x10^2$', '$1.5x10^1$', '$2.0x10^0$','$0.0x10^0$']
otc_text = ['$0.0x10^0$', '$2.2x10^6$', '$1.3x10^5$', '$3.4x10^3$', '$1.3x10^2$', '$2.2x10^2$', '$1.5x10^1$', '$0.0x10^0$','$1.0x10^0$']

fig = plt.figure(figsize=(12, 8))
grid = plt.GridSpec(4, 16, hspace=0.2, wspace=0.2)
ax1 = fig.add_subplot(grid[0:2, 5:])
ax2 = fig.add_subplot(grid[0:2, :4])
ax3 = fig.add_subplot(grid[2:, 5:], sharey=ax1, sharex=ax1)
ax4 = fig.add_subplot(grid[2:, :4], sharey=ax2, sharex=ax2)
#===========================================================================================================#
bars = ax1.bar(y_label,miy, 0.9)

for index, rect in enumerate(bars):
    height = rect.get_height()
    ax1.annotate('{}'.format(mi_text[index]),
                xy=(rect.get_x(), height),va='bottom')
    
ax1.set_yscale('log')
#ax1.set_ylabel('Number Of cluster', fontsize=14)
plt.setp(ax1.get_xticklabels(), visible=False)

Z = midf['len'].to_list()
Z.sort()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)
ax2.plot(X2, F2,label='Cluster Size')
ax2.axhline(y=0.95, color='red', linestyle='dotted')
ax2.axvline(x=Z[int(len(Z)*0.95)],color='red', linestyle='dotted')
ax2.text(Z[int(len(Z)*0.95)]+10, 0.9, f'({Z[int(len(Z)*0.95)]},0.95)', fontsize=10)
#ax2.set_ylabel('Total cluster percentage', fontsize=14)
ax2.set_xscale('log')
#========================================================================================================#
bars = ax3.bar(y_label,otcy, 0.9)

for index, rect in enumerate(bars):
    height = rect.get_height()
    ax3.annotate('{}'.format(otc_text[index]),
                xy=(rect.get_x(), height),va='bottom')
plt.setp(ax2.get_xticklabels(), visible=False)    
ax3.set_yscale('log')
ax3.set_xticklabels(y_label, rotation=15)
ax3.set_ylabel('Number  of cluster', position=(1.5,1),fontsize=14)

Z = df['len'].to_list()
Z.sort()
N = len(Z)
X2 = np.sort(Z)
F2 = np.array(range(N))/float(N)



ax4.plot(X2, F2,label='Cluster Size')
ax4.axhline(y=0.95, color='red', linestyle='dotted')
ax4.axvline(x=Z[int(len(Z)*0.95)],color='red', linestyle='dotted')
ax4.text(Z[int(len(Z)*0.95)]+10, 0.9, f'({Z[int(len(Z)*0.95)]},0.95)', fontsize=10)
#ax4.set_ylabel(', fontsize=14)
ax4.set_xscale('log')

#ax1.axis([0,10, 1, 100000000])




plt.xlabel('Number of address in cluster', fontsize= 14, horizontalalignment='center', verticalalignment='center',position=(1.5,10), labelpad=20)
plt.ylabel('Total cluster percentage', fontsize= 14, horizontalalignment='center', position=(1.5,1), labelpad=10)
#plt.ylabel('Number of cluster', fontsize= 14, horizontalalignment='center', position=(3,1), labelpad=20)
               
plt.show()

# %%
# Sample from a normal distribution using numpy's random number generator
samples = np.random.normal(size=10000)
print(samples)
samples = df['len'].to_list()
# Compute a histogram of the sample
bins = np.linspace(0, max(samples), len(samples))
histogram, bins = np.histogram(samples, bins=bins, density=True)
print(bins)
bin_centers = 0.5*(bins[1:] + bins[:-1])
print(bin_centers)
# Compute the PDF on the bin centers from scipy distribution object
from scipy import stats
pdf = stats.norm.pdf(bin_centers)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 4))
#plt.plot(bin_centers, histogram, label="Histogram of samples")
plt.plot(samples, stats.norm.pdf(samples), label="PDF")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# [-0.74702795 -2.8575833   0.35483005 ... -0.85636119 -0.34155371
#  -1.51498534]
# [0.00000000e+00 7.43372951e+01 1.48674590e+02 ... 1.77430560e+08
#  1.77430635e+08 1.77430709e+08]
# [3.71686475e+01 1.11505943e+02 1.85843238e+02 ... 1.77430523e+08
#  1.77430597e+08 1.77430672e+08]
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/Jupyter-Bitcoin/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     151             try:
# --> 152                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     153             except OverflowError:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# ...

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(109680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = midf['len'].to_list()

num_bins = len(midf['len'].to_list()) // 8

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=1)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %%
def get_addr_from_tag(addr_group):
    s_time = time.time()
    addr_list = cdq.find_addr_from_cluster_num(addr_group)
    cluster_list = list(cdq.get_tag_from_addr(addr_list))
    
    #if len(addr_list) > 10000:
    print(len(addr_list), time.time() - s_time, cluster_list)
    return ",".join(cluster_list)

# %%
result = df.groupby(['number'])

# %%
result.count().head(20)
# Out:
#         address
# number
# 193           3
# 242           2
# 276           5
# 328          10
# 365           2
# 441           8
# 447          10
# 498          39
# 510           2
# 551           6
# 556           2
# 611           3
# 745           8
# 765           2
# 838           3
# 894           2
# 940          10
# 1043          2
# 1060         21
# 1212          6

# %%
cdf = result.count()
